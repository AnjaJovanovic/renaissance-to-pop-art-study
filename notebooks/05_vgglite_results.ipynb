# %% [markdown]
# # 05 VGG-lite rezultati
#
# Krive iz experiments/custom_vgglite/history.csv

# %%
import os
import sys
from pathlib import Path

ROOT = Path("..").resolve()
os.chdir(ROOT)
sys.path.insert(0, str(ROOT / "src"))

# !python src/plot_curves.py
# Out:
# /bin/bash: line 1: python: command not found

# %%
import json
from IPython.display import Image, display

with open("experiments/custom_vgglite/test_metrics.json") as f:
    metrics = json.load(f)
print("test metrics:", metrics)

display(Image("reports/figures/vgglite_curves.png"))
# Out:
# test metrics: {'test_accuracy': 0.35144123435020447, 'test_loss': 1.9121}
