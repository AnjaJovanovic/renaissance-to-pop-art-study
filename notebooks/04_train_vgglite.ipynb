# %% [markdown]
# # Treniranje VGG-lite
#
# Kernel: **Python (pandora venv)**.
#
# Puna runda (`--epochs 20` bez `--steps`) je spora na CPU.

# %%
import os
import sys
from pathlib import Path

ROOT = Path("..").resolve()
os.chdir(ROOT)
sys.path.insert(0, str(ROOT / "src"))

# kratka provera
# !python src/train.py --epochs 1 --steps 10 --val-steps 5
